# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import binom

# パラメータ設定
n = 3   # 試行回数
p = 0.5  # 成功確率
damage = 50

# x軸の値（0 から n までの整数）
x = np.arange(0, n+1)


# 二項分布の確率質量関数 (PMF)
y = binom.pmf(x, n, p)
x = x * damage
# プロット
plt.plot(x, y)


# グラフ表示
plt.show()
